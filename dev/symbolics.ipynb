# %% [markdown]
# # Symbolic Form of DH/MDH and Jacobian

# %%
import sympy as sp
from sympy import init_printing
from sympy import init_session

init_session();
init_printing();
# Out:
# IPython console for SymPy 1.9 (Python 3.8.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
# Define symbolic joint angles
theta = sp.symbols('theta1:7')  # theta1..theta6

# Define symbolic DH parameters
a = sp.symbols('a1:7')          # a1..a6
d = sp.symbols('d1:7')          # d1..d6
alpha = sp.symbols('alpha1:7')  # alpha1..alpha6

def create_dh_matrix(theta, d, a, alpha, modified_DH=True):
    ct = 1 #sp.cos(theta)
    st = 1#sp.sin(theta)
    ca = sp.cos(alpha)
    sa = sp.sin(alpha)
    
    if modified_DH:
        return sp.Matrix([
            [ct, -st, 0, a],
            [st*ca, ct*ca, -sa, -d*sa],
            [st*sa, ct*sa, ca, d*ca],
            [0, 0, 0, 1]
        ])
    else:
        return sp.Matrix([
            [ct, -st*ca, st*sa, a*ct],
            [st, ct*ca, -ct*sa, a*st],
            [0, sa, ca, d],
            [0, 0, 0, 1]
        ])

# %%
frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], a[i], d[i], alpha[i])
    frames.append(frames[-1] * T)

# End-effector position
end_effector_pos = frames[-1][:3, 3]
print("End-effector position:")
print("Coor ee_pos{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# End-effector position:
# Coor ee_pos{ a2*sin(alpha2) - a3*(-cos(alpha2) - 1)*sin(alpha3) + a3*sin(alpha2)*cos(alpha3) + a4*(-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*cos(alpha4) - a4*((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha4) + a5*((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*cos(alpha4) - ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha4))*cos(alpha5) - a5*((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) - (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) - sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha5) + a6*(((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*cos(alpha4) - ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha4))*cos(alpha5) - ((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) - (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) - sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha5))*cos(alpha6) - a6*(((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*cos(alpha4) - ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha4))*sin(alpha5) - (-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) - (-cos(alpha2) - 1)*cos(alpha3) - ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) + ((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) - (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) - sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha5) - sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha6) + d1 + d2 + d3*(1 - cos(alpha2)) + d4*((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) - cos(alpha2) + 1) + d5*((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) + (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) + sin(alpha2)*sin(alpha3) - cos(alpha2) + 1) + d6*(((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*cos(alpha4) - ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*sin(alpha4))*sin(alpha5) + (-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) + (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) + ((-(-cos(alpha2) - 1)*sin(alpha3) + sin(alpha2)*cos(alpha3))*sin(alpha4) - (-cos(alpha2) - 1)*cos(alpha3) + ((-cos(alpha2) - 1)*cos(alpha3) + sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha4) - sin(alpha2)*sin(alpha3) + cos(alpha2) - 1)*cos(alpha5) + sin(alpha2)*sin(alpha3) - cos(alpha2) + 1),
# -a1*sin(alpha1) - a2*sin(alpha1)*cos(alpha2) - a2*sin(alpha2)*cos(alpha1) + a3*(-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - a3*(-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3) + a4*((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*cos(alpha4) - a4*((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha4) + a5*(((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha4))*cos(alpha5) - a5*(((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha4) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha5) + a6*((((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha4))*cos(alpha5) - (((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha4) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha5))*cos(alpha6) - a6*((((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha4))*sin(alpha5) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) + (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + sin(alpha1)*sin(alpha2) - cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha4) + (((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1))*sin(alpha3) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2) - cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha ...
# a1*cos(alpha1) - a2*sin(alpha1)*sin(alpha2) + a2*cos(alpha1)*cos(alpha2) + a3*(-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - a3*(sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3) + a4*((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*cos(alpha4) - a4*((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha4) + a5*(((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha4))*cos(alpha5) - a5*(((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*cos(alpha4) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha5) + a6*((((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha4))*cos(alpha5) - (((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*cos(alpha4) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha5))*cos(alpha6) - a6*((((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*sin(alpha4))*sin(alpha5) - ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) - sin(alpha1)*cos(alpha2) - sin(alpha1) - sin(alpha2)*cos(alpha1))*cos(alpha4) + (((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*sin(alpha3))*sin(alpha4) - (-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) - (sin(alpha1)*cos(alpha2) - sin(alpha1) + sin(alpha2)*cos(alpha1))*cos(alpha3) + ((-sin(alpha1)*sin(alpha2) + cos(alpha1)*cos(alpha2))*sin(alpha3) + (si ...

# %%
p = frames[-1][:3, :3]
p
# Out:
# ⎡
# ⎢
# ⎢((((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)
# ⎢
# ⎣          ((((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂)
#
#
#
# ⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅s
#
# - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅c
#
#
#
# in(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(
#
# os(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(
#
#
#
# α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅cos(α₅) - (((-sin(α₁)⋅cos(α₂) - sin(
#
# α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅cos(α₅) - (((-sin(α₁)⋅sin(α₂
#
#
#
# α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))
#
# ) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅s
#
#
#
# ⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) +
#
# in(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(
#
#
#
# cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin
#
# α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂
#
#
#
# (α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂
#
# ))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅c
#
#
#
# ) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - c
#
# os(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(
#
#
#
# os(α₁))⋅sin(α₅))⋅sin(α₆) + (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-
#
# α₂)⋅cos(α₁))⋅sin(α₅))⋅sin(α₆) + (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃)
#
#                                                                  (((-(-cos(α₂)
#
# sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos
#
#  - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)
#
#  - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅s
#
# (α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁
#
# ⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos
#
# in(α₃) + cos(α₂) - 1)⋅sin(α₄))⋅cos(α₅) - ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅c
#
# ))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅sin(α₅) + (
#
# (α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅sin(α₅)
#
# os(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅s
#
# (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos
#
# + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) +
#
# in(α₃) + cos(α₂) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₅))⋅sin(α₆
#
# (α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) + (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃
#
#  sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(
#
# ) + ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos
#
# ) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂
#
# α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α
#
# (α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₄))⋅sin(α₅) + (-(-cos(α₂) - 1)⋅sin(
#
# ) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅
#
# ₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅
#
# α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) + (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(
#
# cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅c
#
# cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅s
#
# α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) + ((-(-cos(α₂) - 1)⋅sin(α₃) + sin
#
# os(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(
#
# in(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α
#
# (α₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin
#
# α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α
#
# ₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)
#
# (α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₅) +
#
# ₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)
#
# ⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅c
#
#  (((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos(α
#
# ⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + s
#
# os(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(
#
# ₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₄))⋅sin(α₅) - (-(-cos(α₂) - 1)⋅sin(α₃
#
# in(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁
#
# α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) -
#
# ) + sin(α₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) - ((-cos(α₂) - 1)⋅cos(α₃
#
# )⋅cos(α₂) - cos(α₁))⋅cos(α₅) + ((((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃)
#
#  sin(α₂)⋅cos(α₁))⋅cos(α₅) + ((((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) -
#
# ) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) + ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α
#
#  - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁
#
# (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅si
#
# ₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin(α
#
# )⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - c
#
# n(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁
#
# ₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₅) - s
#
# os(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅sin(α₅
#
# ))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅sin(α₅) - (
#
# in(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₆) + sin(α₂)⋅sin(α₃) - cos(α₂) + 1
#
# ) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁
#
# (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + si
#
#
#
# )⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅s
#
# n(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃)
#
#
#
# in(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅c
#
#  - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅sin(α₂)
#
#
#
# os(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(
#
# + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos
#
#
#
# α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + (((-sin(
#
# (α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅sin(
#
#
#
# α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) -
#
# α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))
#
#
#
#  cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-
#
# ⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅co
#
#
#
# sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - si
#
# s(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(
#
#
#
# n(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃
#
# α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)
#
#
#
# ) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - c
#
# ⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - si
#
#
#
# os(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₅) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁
#
# n(α₂)⋅cos(α₁))⋅cos(α₅) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₆)
#
#
#
# ))⋅cos(α₆) - sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) + cos(α₁)  ((((-sin(α₁)⋅cos(α₂)
#
# + sin(α₁)⋅cos(α₂) + sin(α₁) + sin(α₂)⋅cos(α₁)                       ((((-sin(α
#
#
#
#  - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅s
#
# ₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅c
#
#
#
# in(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅si
#
# os(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (si
#
#
#
# n(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂)
#
# n(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁)
#
#
#
#  - cos(α₁))⋅sin(α₄))⋅cos(α₅) - (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃)
#
#  - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅cos(α₅) - (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅
#
#
#
# - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅
#
# cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-s
#
#
#
# cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos
#
# in(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α
#
#
#
# (α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(
#
# ₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)
#
#
#
# α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) -
#
# ⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - si
#
#
#
#  cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₅))⋅sin(
#
# n(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₅))
#
#
#
# α₆) - (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos
#
# ⋅sin(α₆) - (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) -
#
#                                             (((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α
#
# (α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁
#
#  sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅co
#
# ₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)
#
# ))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅
#
# s(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α
#
# ⋅sin(α₄))⋅cos(α₅) - ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) - (-c
#
# sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅cos(α₂) - s
#
# ₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅sin(α₂)
#
# os(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)
#
# in(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α
#
# + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin
#
# ⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₅))⋅sin(α₆) - ((-(-cos(α₂) - 1)
#
# ₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂)
#
# (α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂
#
# ⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃
#
#  + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅
#
# ) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))
#
# ) + cos(α₂) - 1)⋅sin(α₄))⋅sin(α₅) - (-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃)
#
# sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin
#
# ⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos
#
# )⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃)
#
# (α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) - (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(
#
# (α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) - (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(
#
#  + cos(α₂) - 1)⋅cos(α₄) - ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄)
#
# α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄)
#
# α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄)
#
#  - (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂
#
#  - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅
#
# - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) +
#
# ) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₅) + (((-(-cos(α₂) - 1)⋅s
#
# cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (
#
# sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (si
#
# in(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃)
#
# -sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(
#
# n(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁)
#
# + cos(α₂) - 1)⋅sin(α₄))⋅sin(α₅) - (-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅
#
# α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅
#
#  - sin(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos
#
# sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) +
#
# cos(α₅) + ((((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂)
#
# (α₅) + ((((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - si
#
#  cos(α₂) - 1)⋅cos(α₄) + ((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) -
#
# + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅c
#
# n(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α
#
#  (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂)
#
# os(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin
#
# ₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅
#
# - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₅) - sin(α₂)⋅sin(α₃) + cos(
#
# (α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅cos(α₂
#
# cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅sin(α₂) + c
#
# α₂) - 1)⋅cos(α₆) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1
#
# ) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅
#
# os(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃
#
#
#
# sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅si
#
# ))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) -
#
#
#
# n(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(
#
#  sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅si
#
#
#
# α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁
#
# n(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂
#
#
#
# )⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅cos(α₂) - sin(α₂)
#
# ) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂)
#
#
#
# ⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅si
#
# )⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (
#
#
#
# n(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos
#
# -sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin
#
#
#
# (α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃
#
# (α₂)⋅cos(α₁))⋅cos(α₃) + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α
#
#
#
# ) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) -
#
# ₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) -
#
#
#
#  cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(
#
# sin(α₂)⋅cos(α₁))⋅cos(α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₅
#
#
#
# α₁))⋅cos(α₅) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₆) + sin(α₁)⋅
#
# ) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₆) - sin(α₁)⋅cos(α₂) - s
#
#
#
# sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁)  ((((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅c
#
# in(α₁) - sin(α₂)⋅cos(α₁)                   ((((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(
#
#
#
# os(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅cos(α₄) - ((-
#
# α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅cos(α₄)
#
#
#
# sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α
#
# - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) +
#
#
#
# ₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₄))⋅
#
#  sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α
#
#
#
# cos(α₅) - (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) +
#
# ₄))⋅cos(α₅) - (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂
#
#
#
#  cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos
#
# ) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅
#
#
#
# (α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + ((-si
#
# cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) + ((-
#
#              (((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅cos(α₄) - ((-cos(α₂
#
# n(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂)
#
# sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(
#
# ) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₄))⋅cos(α₅) - ((-(-cos(α₂
#
#  - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₄) + s
#
# α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₄) -
#
# ) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) + ((-cos(α₂
#
# in(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₅))⋅cos(α₆) - ((((-sin(α₁)⋅co
#
# sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₅))⋅cos(α₆) - ((((-sin(α₁)⋅s
#
# ) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α₃) + co
#
# s(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α
#
# in(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α
#
# s(α₂) - 1)⋅sin(α₅))⋅cos(α₆) - (((-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅co
#
# ₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α
#
# ₁))⋅sin(α₃))⋅cos(α₄) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁
#
# s(α₄) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₄))⋅sin(
#
# ₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅co
#
# )⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - s
#
# α₅) - (-(-cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos
#
# s(α₂) - cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(
#
# in(α₂)⋅cos(α₁))⋅sin(α₄))⋅sin(α₅) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α
#
# (α₃) - ((-cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) + ((-(
#
# α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(
#
# ₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁
#
# -cos(α₂) - 1)⋅sin(α₃) + sin(α₂)⋅cos(α₃))⋅sin(α₄) - (-cos(α₂) - 1)⋅cos(α₃) + ((
#
# α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) -
#
# )⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅co
#
# -cos(α₂) - 1)⋅cos(α₃) + sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅cos(α₄) - sin(α₂)⋅sin(α
#
#  cos(α₁))⋅cos(α₃) - ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅
#
# s(α₁))⋅cos(α₃) - ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(
#
# ₃) + cos(α₂) - 1)⋅cos(α₅) - sin(α₂)⋅sin(α₃) + cos(α₂) - 1)⋅sin(α₆)
#
# sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α
#
# α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)
#
#
#
# ₂) - cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅cos(α₃) - (-sin
#
# ⋅cos(α₁))⋅cos(α₄) + (((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅cos(α₃) - (sin(α₁)⋅
#
#
#
# (α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅cos(α₂)
#
# cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅sin(α₃))⋅sin(α₄) - (-sin(α₁)⋅sin(α₂) + co
#
#
#
#  - sin(α₂)⋅cos(α₁))⋅sin(α₃) - (-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂) - cos(α₁))⋅c
#
# s(α₁)⋅cos(α₂))⋅sin(α₃) - (sin(α₁)⋅cos(α₂) - sin(α₁) + sin(α₂)⋅cos(α₁))⋅cos(α₃)
#
#
#
# os(α₃) + ((-sin(α₁)⋅cos(α₂) - sin(α₂)⋅cos(α₁))⋅sin(α₃) + (-sin(α₁)⋅sin(α₂) + c
#
#  + ((-sin(α₁)⋅sin(α₂) + cos(α₁)⋅cos(α₂))⋅sin(α₃) + (sin(α₁)⋅cos(α₂) - sin(α₁)
#
#
#
# os(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₃) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁
#
# + sin(α₂)⋅cos(α₁))⋅cos(α₃) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(
#
#
#
# ))⋅cos(α₄) + sin(α₁)⋅sin(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅cos(α₅) + sin(α₁)⋅si
#
# α₄) - sin(α₁)⋅cos(α₂) - sin(α₁) - sin(α₂)⋅cos(α₁))⋅cos(α₅) - sin(α₁)⋅cos(α₂) -
#
#                                           ⎤
#                                           ⎥
# n(α₂) - cos(α₁)⋅cos(α₂) - cos(α₁))⋅sin(α₆)⎥
#                                           ⎥
#  sin(α₁) - sin(α₂)⋅cos(α₁))⋅sin(α₆)       ⎦

# %%
dh_params = [
    (167.719,1, 0.0),
    (19.898, 1, sp.pi/2),
    (-0.39, 250.201, 0 ),
    (231.03, 1, sp.pi/2),
    (2.785, 1, -sp.pi/2),
    (140.54, 1, sp.pi/2)
]

frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], *dh_params[i])
    frames.append(frames[-1] * T)


end_effector_pos = frames[-1][:3, 3]
print("End-effector position:")
print("Coor ee_pos{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# End-effector position:
# Coor ee_pos{ 1158.174,
# 827.50799999999992,
# 699.42999999999995 };

# %%
dh_params = [
    (167.719,1, 0.0),
    (19.898, 1, sp.pi/2),
    (-0.39, 250.201, 0 ),
    (231.03, 1, sp.pi/2),
    (2.785, 1, -sp.pi/2),
    (140.54, 1, sp.pi/2)
]

frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], *dh_params[i])
    frames.append(frames[-1] * T)


h03 = frames[3]#[:3, 3]
print("h03:")
print("Matrix4d h03{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# h03:
# Matrix4d h03{ 1158.174,
# 827.50799999999992,
# 699.42999999999995 };

# %%
sp.simplify(frames[3])
# Out:
# ⎡0  -2  1   271.709⎤
# ⎢                  ⎥
# ⎢0  -2  -1  231.693⎥
# ⎢                  ⎥
# ⎢2  0   0   417.92 ⎥
# ⎢                  ⎥
# ⎣0  0   0      1   ⎦

# %%
h36 = frames[-1] * frames[3]
print("h36:")
print("Matrix4d h36{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# h36:
# Matrix4d h36{ 1158.174,
# 827.50799999999992,
# 699.42999999999995 };

# %%
sp.Matrix(h03) * sp.Matrix(h36)
# Out:
# ⎡0    0   16  -363.749 ⎤
# ⎢                      ⎥
# ⎢-8  -16  8   -1620.761⎥
# ⎢                      ⎥
# ⎢12  -8   -4   6168.56 ⎥
# ⎢                      ⎥
# ⎣0    0   0       1    ⎦

# %%
[sp.simplify(p) for p in frames[-1]]
# Out:
# [0, 2, 3, 1158.174, -4, 2, 1, 827.508, 0, -4, 2, 699.43, 0, 0, 0, 1]

# %%
# zyz
thetaz = sp.symbols('thetaz')
thetay = sp.symbols('thetay')
thetax = sp.symbols('thetax')

phi = sp.symbols('phi')
psi = sp.symbols('psi')
theta = sp.symbols('theta')

# rx = sp.Matrix([[1, 0, 0],
#                 [0, sp.cos(thetax),-sp.sin(thetax)],
#                 [0, sp.sin(thetax), sp.cos(thetax)]])

rytheta = sp.Matrix([[sp.cos(theta), 0, sp.sin(theta)],
                     [0, 1, 0],
                     [-sp.sin(theta), 0, sp.cos(theta)]])

rzpsi = sp.Matrix([[sp.cos(psi), -sp.sin(psi), 0],
                   [sp.sin(psi), sp.cos(psi), 0],
                   [0, 0, 1]])

rzphi = sp.Matrix([[sp.cos(phi), -sp.sin(phi), 0],
                    [sp.sin(phi), sp.cos(phi), 0],
                    [0, 0, 1]])

R = rzphi * rytheta * rzpsi
print("Matrix3d R{", ",\r\n".join([sp.ccode(sp.simplify(p)) for p in R]), "};")
R
# Out:
# Matrix3d R{ -sin(phi)*sin(psi) + cos(phi)*cos(psi)*cos(theta),
# -sin(phi)*cos(psi) - sin(psi)*cos(phi)*cos(theta),
# sin(theta)*cos(phi),
# sin(phi)*cos(psi)*cos(theta) + sin(psi)*cos(phi),
# -sin(phi)*sin(psi)*cos(theta) + cos(phi)*cos(psi),
# sin(phi)*sin(theta),
# -sin(theta)*cos(psi),
# sin(psi)*sin(theta),
# cos(theta) };
# ⎡-sin(φ)⋅sin(ψ) + cos(φ)⋅cos(ψ)⋅cos(θ)  -sin(φ)⋅cos(ψ) - sin(ψ)⋅cos(φ)⋅cos(θ)
# ⎢
# ⎢sin(φ)⋅cos(ψ)⋅cos(θ) + sin(ψ)⋅cos(φ)   -sin(φ)⋅sin(ψ)⋅cos(θ) + cos(φ)⋅cos(ψ)
# ⎢
# ⎣           -sin(θ)⋅cos(ψ)                          sin(ψ)⋅sin(θ)
#
#  sin(θ)⋅cos(φ)⎤
#               ⎥
#  sin(φ)⋅sin(θ)⎥
#               ⎥
#     cos(θ)    ⎦

# %%
# zyx roll pithc yaw
thetaz = sp.symbols('thetaz')
thetay = sp.symbols('thetay')
thetax = sp.symbols('thetax')

phi = sp.symbols('phi')
psi = sp.symbols('psi')
theta = sp.symbols('theta')

rxpsi = sp.Matrix([[1, 0, 0],
                [0, sp.cos(psi),-sp.sin(psi)],
                [0, sp.sin(psi), sp.cos(psi)]])

rytheta = sp.Matrix([[sp.cos(theta), 0, sp.sin(theta)],
                     [0, 1, 0],
                     [-sp.sin(theta), 0, sp.cos(theta)]])

rzphi = sp.Matrix([[sp.cos(phi), -sp.sin(phi), 0],
                [sp.sin(phi), sp.cos(phi), 0],
                [0, 0, 1]])

R = rzphi * rytheta * rxpsi
print("Matrix3d R{", ",\r\n".join([sp.ccode(sp.simplify(p)) for p in R]), "};")
R
# Out:
# Matrix3d R{ cos(phi)*cos(theta),
# -sin(phi)*cos(psi) + sin(psi)*sin(theta)*cos(phi),
# sin(phi)*sin(psi) + sin(theta)*cos(phi)*cos(psi),
# sin(phi)*cos(theta),
# sin(phi)*sin(psi)*sin(theta) + cos(phi)*cos(psi),
# sin(phi)*sin(theta)*cos(psi) - sin(psi)*cos(phi),
# -sin(theta),
# sin(psi)*cos(theta),
# cos(psi)*cos(theta) };
# ⎡cos(φ)⋅cos(θ)  -sin(φ)⋅cos(ψ) + sin(ψ)⋅sin(θ)⋅cos(φ)  sin(φ)⋅sin(ψ) + sin(θ)⋅
# ⎢
# ⎢sin(φ)⋅cos(θ)  sin(φ)⋅sin(ψ)⋅sin(θ) + cos(φ)⋅cos(ψ)   sin(φ)⋅sin(θ)⋅cos(ψ) -
# ⎢
# ⎣   -sin(θ)                 sin(ψ)⋅cos(θ)                         cos(ψ)⋅cos(θ
#
# cos(φ)⋅cos(ψ)⎤
#              ⎥
# sin(ψ)⋅cos(φ)⎥
#              ⎥
# )            ⎦
