# %% [markdown]
# # Symbolic Form of DH/MDH and Jacobian

# %%
import sympy as sp
from sympy import init_printing
from sympy import init_session

init_session();
init_printing();
# Out:
# IPython console for SymPy 1.9 (Python 3.8.2-64-bit) (ground types: python)
#
# These commands were executed:
# >>> from __future__ import division
# >>> from sympy import *
# >>> x, y, z, t = symbols('x y z t')
# >>> k, m, n = symbols('k m n', integer=True)
# >>> f, g, h = symbols('f g h', cls=Function)
# >>> init_printing()
#
# Documentation can be found at https://docs.sympy.org/1.9/

# %%
# Define symbolic joint angles
theta = sp.symbols('theta1:7')  # theta1..theta6

# Define symbolic DH parameters
a = sp.symbols('a1:7')          # a1..a6
d = sp.symbols('d1:7')          # d1..d6
alpha = sp.symbols('alpha1:7')  # alpha1..alpha6

def create_dh_matrix(theta, d, a, alpha, modified_DH=True):
    ct = sp.cos(theta)
    st = sp.sin(theta)
    ca = sp.cos(alpha)
    sa = sp.sin(alpha)
    
    if modified_DH:
        return sp.Matrix([
            [ct, -st, 0, a],
            [st*ca, ct*ca, -sa, -d*sa],
            [st*sa, ct*sa, ca, d*ca],
            [0, 0, 0, 1]
        ])
    else:
        return sp.Matrix([
            [ct, -st*ca, st*sa, a*ct],
            [st, ct*ca, -ct*sa, a*st],
            [0, sa, ca, d],
            [0, 0, 0, 1]
        ])

# %%
frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], a[i], d[i], alpha[i])
    frames.append(frames[-1] * T)

# End-effector position
end_effector_pos = frames[-1][:3, 3]
print("End-effector position:")
print("Coor ee_pos{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# End-effector position:
# Coor ee_pos{ a2*sin(alpha2)*sin(theta1) - a3*(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + a3*sin(alpha2)*sin(theta1)*cos(alpha3) + a4*(-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*cos(alpha4) - a4*(-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*sin(alpha4) + a5*((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*cos(alpha4) - (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*sin(alpha4))*cos(alpha5) - a5*((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*sin(alpha4)*cos(theta4) + (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*cos(alpha4)*cos(theta4) - ((-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*cos(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(theta3)*cos(alpha3) + sin(alpha2)*sin(alpha3)*sin(theta1)*sin(theta3))*sin(theta4))*sin(alpha5) + a6*(((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*cos(alpha4) - (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*sin(alpha4))*cos(alpha5) - ((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*sin(alpha4)*cos(theta4) + (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*cos(alpha4)*cos(theta4) - ((-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*cos(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(theta3)*cos(alpha3) + sin(alpha2)*sin(alpha3)*sin(theta1)*sin(theta3))*sin(theta4))*sin(alpha5))*cos(alpha6) - a6*(((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*cos(alpha4) - (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*sin(alpha4))*sin(alpha5)*cos(theta5) - ((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*sin(alpha4)*sin(theta4) + (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3))*sin(theta4)*cos(alpha4) + ((-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*cos(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(theta3)*cos(alpha3) + sin(alpha2)*sin(alpha3)*sin(theta1)*sin(theta3))*cos(theta4))*sin(theta5) + ((-(-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*sin(alpha3) + sin(alpha2)*sin(theta1)*cos(alpha3))*sin(alpha4)*cos(theta4) + (-(-sin(theta1)*sin(theta2)*cos(alpha2) + cos(theta1)*cos(theta2))*sin(theta3) + (-sin(theta1)*cos(alpha2)*cos(theta2) - sin(theta2)*cos(theta1))*cos(alpha3)*cos(theta3) + sin(alpha2)*sin(alpha3)*sin(theta1)*cos(theta3 ...
# -a1*sin(alpha1) - a2*sin(alpha1)*cos(alpha2) - a2*sin(alpha2)*cos(alpha1)*cos(theta1) + a3*(-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - a3*(-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3) + a4*((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3))*cos(alpha4) - a4*((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*cos(theta3) - (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*sin(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*cos(alpha3)*cos(theta3))*sin(alpha4) + a5*(((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*cos(theta3) - (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*sin(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*cos(alpha3)*cos(theta3))*sin(alpha4))*cos(alpha5) - a5*(((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3))*sin(alpha4)*cos(theta4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*sin(theta3) + (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*cos(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(theta3)*cos(alpha3))*sin(theta4) + ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*cos(theta3) - (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*sin(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*cos(alpha3)*cos(theta3))*cos(alpha4)*cos(theta4))*sin(alpha5) + a6*((((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*cos(theta3) - (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*sin(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*cos(alpha3)*cos(theta3))*sin(alpha4))*cos(alpha5) - (((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*cos(alpha3) - (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(alpha3))*sin(alpha4)*cos(theta4) - ((-sin(alpha1)*cos(alpha2) - sin(alpha2)*cos(alpha1)*cos(theta1))*sin(alpha3)*sin(theta3) + (-sin(alpha1)*sin(alpha2)*sin(theta2) + sin(theta1)*cos(alpha1)*cos(theta2) + sin(theta2)*cos(alpha1)*cos(alpha2)*cos(theta1))*cos(theta3) + (-sin(alpha1)*sin(alpha2)*cos(theta2) - sin(theta1)*sin(theta2)*cos(alpha1) + cos(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2))*sin(theta3)*cos(alpha3))*sin(theta4) + ((-sin(alpha1)*cos(alpha2)  ...
# a1*cos(alpha1) - a2*sin(alpha1)*sin(alpha2)*cos(theta1) + a2*cos(alpha1)*cos(alpha2) + a3*(-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - a3*(-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3) + a4*((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3))*cos(alpha4) - a4*((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*cos(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*cos(alpha3)*cos(theta3) - (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*sin(theta3))*sin(alpha4) + a5*(((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*cos(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*cos(alpha3)*cos(theta3) - (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*sin(theta3))*sin(alpha4))*cos(alpha5) - a5*(((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3))*sin(alpha4)*cos(theta4) - ((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*sin(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(theta3)*cos(alpha3) + (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*cos(theta3))*sin(theta4) + ((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*cos(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*cos(alpha3)*cos(theta3) - (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*sin(theta3))*cos(alpha4)*cos(theta4))*sin(alpha5) + a6*((((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3))*cos(alpha4) - ((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*cos(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*cos(alpha3)*cos(theta3) - (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*sin(theta3))*sin(alpha4))*cos(alpha5) - (((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*cos(alpha3) - (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(alpha3))*sin(alpha4)*cos(theta4) - ((-sin(alpha1)*sin(alpha2)*cos(theta1) + cos(alpha1)*cos(alpha2))*sin(alpha3)*sin(theta3) + (-sin(alpha1)*sin(theta1)*sin(theta2) + sin(alpha1)*cos(alpha2)*cos(theta1)*cos(theta2) + sin(alpha2)*cos(alpha1)*cos(theta2))*sin(theta3)*cos(alpha3) + (sin(alpha1)*sin(theta1)*cos(theta2) + sin(alpha1)*sin(theta2)*cos(alpha2)*cos(theta1) + sin(alpha2)*sin(theta2)*cos(alpha1))*cos(theta3))*sin(theta4) + ((-sin(alpha1)*sin(alpha2)*cos(the ...

# %%
dh_params = [
    (167.719,1, 0.0),
    (19.898, 1, sp.pi/2),
    (-0.39, 250.201, 0 ),
    (231.03, 1, sp.pi/2),
    (2.785, 1, -sp.pi/2),
    (140.54, 1, sp.pi/2)
]

frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], *dh_params[i])
    frames.append(frames[-1] * T)


end_effector_pos = frames[-1][:3, 3]
print("End-effector position:")
print("Coor ee_pos{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# End-effector position:
# Coor ee_pos{ 140.53999999999999*((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*sin(theta5) + ((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*cos(theta5) - 2.7850000000000001*(-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*cos(theta5) + sin(theta1)*sin(theta4) + 2.7850000000000001*sin(theta1)*cos(theta4) + 19.507999999999999*sin(theta1) - sin(theta2)*sin(theta3)*cos(theta1) + 231.03*sin(theta2)*cos(theta1)*cos(theta3) + 231.03*sin(theta3)*cos(theta1)*cos(theta2) + cos(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*cos(theta1)*cos(theta2) + cos(theta1) + 1,
# 140.53999999999999*((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*sin(theta5) + ((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*cos(theta5) - 2.7850000000000001*(-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*cos(theta5) - sin(theta1)*sin(theta2)*sin(theta3) + 231.03*sin(theta1)*sin(theta2)*cos(theta3) + 231.03*sin(theta1)*sin(theta3)*cos(theta2) + sin(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*sin(theta1)*cos(theta2) + sin(theta1) - sin(theta4)*cos(theta1) - 2.7850000000000001*cos(theta1)*cos(theta4) - 19.507999999999999*cos(theta1),
# -(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*sin(theta5) + 140.53999999999999*(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*cos(theta5) - 2.7850000000000001*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta4) + 140.53999999999999*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta5)*cos(theta4) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4)*cos(theta5) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4) + 231.03*sin(theta2)*sin(theta3) + sin(theta2)*cos(theta3) + 250.20099999999999*sin(theta2) + sin(theta3)*cos(theta2) - 231.03*cos(theta2)*cos(theta3) + 167.71899999999999 };

# %%
dh_params = [
    (167.719,1, 0.0),
    (19.898, 1, sp.pi/2),
    (-0.39, 250.201, 0 ),
    (231.03, 1, sp.pi/2),
    (2.785, 1, -sp.pi/2),
    (140.54, 1, sp.pi/2)
]

frames = [sp.eye(4)]
for i in range(len(theta)):
    T = create_dh_matrix(theta[i], *dh_params[i])
    frames.append(frames[-1] * T)


h03 = frames[3]#[:3, 3]
print("h03:")
print("Matrix4d h03{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# h03:
# Matrix4d h03{ 140.53999999999999*((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*sin(theta5) + ((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*cos(theta5) - 2.7850000000000001*(-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*cos(theta5) + sin(theta1)*sin(theta4) + 2.7850000000000001*sin(theta1)*cos(theta4) + 19.507999999999999*sin(theta1) - sin(theta2)*sin(theta3)*cos(theta1) + 231.03*sin(theta2)*cos(theta1)*cos(theta3) + 231.03*sin(theta3)*cos(theta1)*cos(theta2) + cos(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*cos(theta1)*cos(theta2) + cos(theta1) + 1,
# 140.53999999999999*((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*sin(theta5) + ((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*cos(theta5) - 2.7850000000000001*(-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*cos(theta5) - sin(theta1)*sin(theta2)*sin(theta3) + 231.03*sin(theta1)*sin(theta2)*cos(theta3) + 231.03*sin(theta1)*sin(theta3)*cos(theta2) + sin(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*sin(theta1)*cos(theta2) + sin(theta1) - sin(theta4)*cos(theta1) - 2.7850000000000001*cos(theta1)*cos(theta4) - 19.507999999999999*cos(theta1),
# -(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*sin(theta5) + 140.53999999999999*(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*cos(theta5) - 2.7850000000000001*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta4) + 140.53999999999999*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta5)*cos(theta4) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4)*cos(theta5) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4) + 231.03*sin(theta2)*sin(theta3) + sin(theta2)*cos(theta3) + 250.20099999999999*sin(theta2) + sin(theta3)*cos(theta2) - 231.03*cos(theta2)*cos(theta3) + 167.71899999999999 };

# %%
frames[3]
# Out:
# ⎡-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)  -sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
# ⎢
# ⎢-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)  -sin(θ₁)⋅sin(θ₂)⋅cos(θ₃)
# ⎢
# ⎢        sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂)                   -sin(θ₂)⋅sin(θ₃)
# ⎢
# ⎣                        0                                                   0
#
# - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)  sin(θ₁)   19.508⋅sin(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂)
#
# - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)  -cos(θ₁)    250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - 19.
#
# + cos(θ₂)⋅cos(θ₃)             0                    250.201⋅sin(θ₂) + 167.719
#
#                               0                                1
#
# + cos(θ₁) + 1⎤
#              ⎥
# 508⋅cos(θ₁)  ⎥
#              ⎥
#              ⎥
#              ⎥
#              ⎦

# %%
h36 = frames[-1] * frames[3]
print("h36:")
print("Matrix4d h36{", ",\r\n".join([sp.ccode(p) for p in end_effector_pos]), "};")
# Out:
# h36:
# Matrix4d h36{ 140.53999999999999*((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*sin(theta5) + ((-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) + sin(theta1)*sin(theta4))*cos(theta5) - 2.7850000000000001*(-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta2)*sin(theta3)*cos(theta1) + cos(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta2)*cos(theta1)*cos(theta3) + sin(theta3)*cos(theta1)*cos(theta2))*cos(theta5) + sin(theta1)*sin(theta4) + 2.7850000000000001*sin(theta1)*cos(theta4) + 19.507999999999999*sin(theta1) - sin(theta2)*sin(theta3)*cos(theta1) + 231.03*sin(theta2)*cos(theta1)*cos(theta3) + 231.03*sin(theta3)*cos(theta1)*cos(theta2) + cos(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*cos(theta1)*cos(theta2) + cos(theta1) + 1,
# 140.53999999999999*((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*sin(theta5) + ((-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - sin(theta4)*cos(theta1))*cos(theta5) - 2.7850000000000001*(-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*sin(theta4) + (-sin(theta1)*sin(theta2)*sin(theta3) + sin(theta1)*cos(theta2)*cos(theta3))*cos(theta4) - (sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*sin(theta5) + 140.53999999999999*(sin(theta1)*sin(theta2)*cos(theta3) + sin(theta1)*sin(theta3)*cos(theta2))*cos(theta5) - sin(theta1)*sin(theta2)*sin(theta3) + 231.03*sin(theta1)*sin(theta2)*cos(theta3) + 231.03*sin(theta1)*sin(theta3)*cos(theta2) + sin(theta1)*cos(theta2)*cos(theta3) + 250.20099999999999*sin(theta1)*cos(theta2) + sin(theta1) - sin(theta4)*cos(theta1) - 2.7850000000000001*cos(theta1)*cos(theta4) - 19.507999999999999*cos(theta1),
# -(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*sin(theta5) + 140.53999999999999*(sin(theta2)*sin(theta3) - cos(theta2)*cos(theta3))*cos(theta5) - 2.7850000000000001*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta4) + 140.53999999999999*(sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*sin(theta5)*cos(theta4) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4)*cos(theta5) + (sin(theta2)*cos(theta3) + sin(theta3)*cos(theta2))*cos(theta4) + 231.03*sin(theta2)*sin(theta3) + sin(theta2)*cos(theta3) + 250.20099999999999*sin(theta2) + sin(theta3)*cos(theta2) - 231.03*cos(theta2)*cos(theta3) + 167.71899999999999 };

# %%
sp.Matrix(h03) * sp.Matrix(h36)
# Out:
# ⎡(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅c
# ⎢
# ⎢(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅c
# ⎢
# ⎢
# ⎢
# ⎣
#
# os(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂
#
# os(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂
#
#
#
#
#
# )⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅si
#
# )⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅si
#
#
#
#
#
# n(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(
#
# n(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(
#
#
#
#
#
# -sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos
#
# -sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos
#
# (-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅
#
#
#
# (θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅
#
# (θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅
#
# cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃)
#
#
#
# cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(
#
# cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(
#
#  + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + s
#
#
#
# θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-s
#
# θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-s
#
# in(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅
#
#
#
# in(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁
#
# in(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁
#
# sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅co
#
#
#
# ) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos
#
# ) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos
#
# s(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) +
#
#
#
# (θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅co
#
# (θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅co
#
#  sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin
#
#
#
# s(θ₂))) + (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅((-(((-sin(θ₁)⋅
#
# s(θ₂))) + (-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅((-(((-sin(θ₁)⋅
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅co
#
#
#
# sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅)
#
# sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅)
#
# s(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ
#
#
#
# - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-s
#
# - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-s
#
# ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + si
#
#
#
# in(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅c
#
# in(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅c
#
# n(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))) + (sin(θ₂
#
#                                                                     0
#
# os(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₁)⋅si
#
# os(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₁)⋅si
#
# )⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅
#
#
#
# n(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) -
#
# n(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) -
#
# cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ
#
#
#
# (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin
#
# (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin
#
# ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅c
#
#
#
# (θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin
#
# (θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin
#
# os(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
#
#
# (θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₁)⋅sin(θ
#
# (θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₁)⋅sin(θ
#
# + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅co
#
#
#
# ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (si
#
# ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (si
#
# s(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)
#
#
#
# n(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + s
#
# n(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + s
#
# ⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos
#
#
#
# in(θ₃)⋅cos(θ₂))) + ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)
#
# in(θ₃)⋅cos(θ₂))) - ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)
#
# (θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) +
#
#
#
# ⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(
#
# ⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(
#
# cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ
#
#
#
# θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(
#
# θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(
#
# ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅co
#
#
#
# θ₃)) + ((-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin
#
# θ₃)) + ((-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin
#
# s(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂)))
#
#
#
# (θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅s
#
# (θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅s
#
#
#
#
#
# in(θ₄)⋅sin(θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((sin(θ
#
# in(θ₄)⋅sin(θ₆))⋅(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + ((sin(θ
#
#
#
#
#
# ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅si
#
# ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅si
#
#
#
#
#
# n(θ₅)⋅cos(θ₄))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂)))⋅sin(θ₁)  (-sin(θ₂)⋅sin(θ₃)
#
# n(θ₅)⋅cos(θ₄))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂)))⋅cos(θ₁)  (-sin(θ₁)⋅sin(θ₂)
#
#
#
#
#
# ⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅c
#
# ⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅c
#
#
#
#
#
# os(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
#
# os(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃)
#
#
#
#
#
# + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + co
#
# + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + co
#
#
#
#
#
# s(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅c
#
# s(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅c
#
#                                                             (-sin(θ₂)⋅sin(θ₃)
#
#
#
# os(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos
#
# os(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos
#
# + cos(θ₂)⋅cos(θ₃))⋅((-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅c
#
#
#
# (θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) +
#
# (θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) +
#
# os(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)
#
#
#
# sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(
#
# sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(
#
# ⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos
#
#
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅cos(θ₁)⋅cos
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅cos(θ₁)⋅cos
#
# (θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅
#
#
#
# (θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂
#
# (θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂
#
# sin(θ₃)⋅cos(θ₂)) + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos
#
#
#
# )⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin
#
# )⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin
#
# (θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅c
#
#
#
# (θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))) + (-sin(θ
#
# (θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))) + (-sin(θ
#
# os(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ
#
#
#
# ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅((-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) +
#
# ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅((-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) +
#
# ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅co
#
#
#
#  sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂
#
#  sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂
#
# s(θ₁)⋅cos(θ₂)) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄
#
#
#
# )⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅si
#
# )⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅si
#
# ) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(
#
#
#
# n(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)
#
# n(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)
#
# θ₂))⋅cos(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃))) + (sin(θ₂)⋅cos(θ₃) + sin(θ
#
#                                                     0
#
# ⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + s
#
# ⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + s
#
# ₃)⋅cos(θ₂))⋅((-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄)
#
#
#
# in(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅
#
# in(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅
#
# + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂
#
#
#
# cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(
#
# cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(
#
# ))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅s
#
#
#
# θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅c
#
# θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅c
#
# in(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)
#
#
#
# os(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(
#
# os(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(
#
# ⋅cos(θ₂)) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) +
#
#
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ₂)⋅cos
#
# sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))
#
#
#
# (θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)))
#
# (θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)))
#
# ⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin
#
#
#
#  + ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ
#
#  - ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ
#
# (θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅c
#
#
#
# ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin
#
# ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin
#
# os(θ₂)) + (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin
#
#
#
# (θ₄)⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((-(sin(θ
#
# (θ₄)⋅cos(θ₆))⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅cos(θ₂)) + ((-(sin(θ
#
# (θ₁)⋅sin(θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅co
#
#
#
# ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅co
#
# ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅co
#
# s(θ₅))⋅(-sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)))
#
#
#
# s(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆))⋅
#
# s(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆))⋅
#
#
#
#
#
# (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + ((sin(θ₂)⋅sin(θ₃) - cos
#
# (-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)) + ((sin(θ₂)⋅sin(θ₃) - cos
#
#
#
#
#
# (θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄))⋅(
#
# (θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄))⋅(
#
#
#
#
#
# -sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)))⋅sin(θ₁)  (-(-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
# -sin(θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)))⋅cos(θ₁)  (-(-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
#
#
#
#
# + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ
#
# + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ
#
#
#
#
#
# ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅s
#
# ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅s
#
#
#
#
#
# in(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁)
#
# in(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁)
#
#          (-(-(((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) -
#
#
#
# + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅co
#
# + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅co
#
# sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))
#
#
#
# s(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅
#
# s(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅
#
# ⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin
#
#
#
# cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos
#
# cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos
#
# (θ₄) - cos(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁) + ((((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(
#
#
#
# (θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅sin(θ₁))⋅(-sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) - sin(θ₃)⋅cos(θ₁)⋅co
#
# (θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅sin(θ₁))⋅(-sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) - sin(θ₁)⋅sin(θ₃)⋅co
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅cos
#
#
#
# s(θ₂)) + (-(-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) +
#
# s(θ₂)) + (-(-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) +
#
# (θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
#
#
# sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))
#
# sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))
#
#  + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅sin(θ₁))⋅(-sin
#
#
#
# ⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin
#
# ⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin
#
# (θ₂)⋅sin(θ₃) + cos(θ₂)⋅cos(θ₃)) + (-(-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅co
#
#                                 0
#
# (θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(
#
# (θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁) + ((((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(
#
# s(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) +
#
#
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos
#
# θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos
#
#  sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos
#
#
#
# (θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁)
#
# (θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁)
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅cos(θ₁) + ((((-sin(θ
#
#
#
#  + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅sin(θ₁))⋅(-sin
#
#  + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅sin(θ₁))⋅(-sin
#
# ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ
#
#
#
# (θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃)) + (-(-(-(sin(θ₂)⋅sin(θ₃) - cos
#
# (θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃)) - (-(-(-(sin(θ₂)⋅sin(θ₃) - cos
#
# ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-
#
#
#
# (θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅s
#
# (θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅s
#
# (-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅cos(θ₄)
#
#
#
# in(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅cos(θ₁) + ((-(si
#
# in(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅cos(θ₁) + ((-(si
#
# )⋅sin(θ₆))⋅sin(θ₁))⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))
#
#
#
# n(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))
#
# n(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))
#
#
#
#
#
# ⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆
#
# ⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆
#
#
#
#
#
# ))⋅sin(θ₁))⋅sin(θ₁)  (-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((-(
#
# ))⋅sin(θ₁))⋅cos(θ₁)    (-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅((
#
#
#
#
#
# ((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄
#
# -(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(
#
#
#
#
#
# ))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅sin(
#
# θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅si
#
#
#
#
#
# θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)
#
# n(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ
#
#
#
#
#
# ⋅cos(θ₄))⋅cos(θ₆))⋅(250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - 19.508⋅cos(θ₁)) + ((((
#
# ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - 19.508⋅cos(θ₁)) + ((
#
#
#
#
#
# -sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))
#
# ((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄
#
#
#
#
#
# ⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆
#
# ))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos(
#
#
#
#
#
# ) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)⋅c
#
# θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁)
#
# ...
#
# in(θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂) + sin
#
#
#
# in(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂)⋅
#
#  sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - (sin(θ₁)⋅sin(θ₂
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃) + 250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - sin(θ₄)⋅cos(θ₁) - 2
#
#
#
# cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅sin(
#
# )⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅))⋅cos(θ₆) + (-(-sin(θ₁)⋅sin(θ₂)⋅si
#
# .785⋅cos(θ₁)⋅cos(θ₄) - 19.508⋅cos(θ₁)) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅(
#
#                                                        1
#
# θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(19.508⋅sin
#
# n(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) - cos(θ₁)⋅cos(θ₄))⋅sin(θ₆))⋅(19.508⋅s
#
# (-(((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin
#
#
#
# (θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂) + cos(θ₁) + 1) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) +
#
# in(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂) + cos(θ₁) + 1) + (((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃)
#
# (θ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅s
#
#
#
# sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ₂)
#
# + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + (sin(θ₁)⋅sin(θ
#
# in(θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(
#
#
#
# ⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(250.201⋅sin(θ₂) + 167.719) + 140
#
# ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅))⋅(250.201⋅sin(θ₂) + 167.719) + 1
#
# θ₁)⋅cos(θ₄))⋅cos(θ₆))⋅(250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - 19.508⋅cos(θ₁)) + (
#
#
#
# .54⋅((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅co
#
# 40.54⋅((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - sin(θ₄)⋅
#
# (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ
#
#
#
# s(θ₁))⋅sin(θ₅) + ((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄)
#
# cos(θ₁))⋅sin(θ₅) + ((-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ
#
# ₄))⋅cos(θ₅) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅sin(θ₅))⋅cos
#
#
#
#  - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - 2.785⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂
#
# ₄) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - 2.785⋅(-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(
#
# (θ₆) + (-(-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + sin(θ₁
#
#
#
# )⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(
#
# θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₁)⋅sin(θ₂)⋅sin(θ₃) + sin(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅co
#
# )⋅cos(θ₄))⋅sin(θ₆))⋅(19.508⋅sin(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂) + cos(θ₁) + 1) +
#
#
#
# θ₄) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅) + 140.54⋅(si
#
# s(θ₄) - (sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅sin(θ₅) + 140.54⋅(
#
#  (((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(
#
#
#
# n(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅) - sin(θ₁)⋅sin(θ₂)⋅sin
#
# sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + sin(θ₁)⋅sin(θ₃)⋅cos(θ₂))⋅cos(θ₅) - sin(θ₁)⋅sin(θ₂)⋅s
#
# θ₄))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂))⋅cos(θ₅))⋅(2
#
#
#
# (θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂) + sin(θ
#
# in(θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₂)⋅cos(θ₃) + 231.03⋅sin(θ₁)⋅sin(θ₃)⋅cos(θ₂) + sin
#
# 50.201⋅sin(θ₂) + 167.719) + 140.54⋅((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂
#
#
#
# ₁)⋅cos(θ₂)⋅cos(θ₃) + 250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - sin(θ₄)⋅cos(θ₁) - 2.7
#
# (θ₁)⋅cos(θ₂)⋅cos(θ₃) + 250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - sin(θ₄)⋅cos(θ₁) - 2
#
# )⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅sin(θ₅) + ((-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁) + c
#
#
#
# 85⋅cos(θ₁)⋅cos(θ₄) - 19.508⋅cos(θ₁)) + ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃)
#
# .785⋅cos(θ₁)⋅cos(θ₄) - 19.508⋅cos(θ₁)) - ((-(-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ
#
# os(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) + sin(θ₁)⋅sin(θ₄))⋅cos(θ₅) - 2.785⋅(-sin(θ₂)⋅s
#
#
#
# )⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (si
#
# ₃))⋅sin(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆) - (
#
# in(θ₃)⋅cos(θ₁) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅sin(θ₄) + (-sin(θ₂)⋅sin(θ₃)⋅cos(θ₁)
#
#
#
# n(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅(250.201⋅sin(θ₁)⋅cos(θ₂) + s
#
# sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅cos(θ₆))⋅(250.201⋅sin(θ₁)⋅cos(θ₂) +
#
# + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃))⋅cos(θ₄) - (sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁
#
#
#
# in(θ₁) - 19.508⋅cos(θ₁)) + ((-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + (s
#
#  sin(θ₁) - 19.508⋅cos(θ₁)) + ((-(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) +
#
# )⋅cos(θ₂))⋅sin(θ₅) + 140.54⋅(sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₁)⋅cos(θ₂)
#
#
#
# in(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃)
#
# (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - (sin(θ₂)⋅cos(θ₃
#
# )⋅cos(θ₅) + sin(θ₁)⋅sin(θ₄) + 2.785⋅sin(θ₁)⋅cos(θ₄) + 19.508⋅sin(θ₁) - sin(θ₂)
#
#
#
# + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆))⋅(19.508⋅sin(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂)
#
# ) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄)⋅sin(θ₆))⋅(19.508⋅sin(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂
#
# ⋅sin(θ₃)⋅cos(θ₁) + 231.03⋅sin(θ₂)⋅cos(θ₁)⋅cos(θ₃) + 231.03⋅sin(θ₃)⋅cos(θ₁)⋅cos
#
#
#
# + cos(θ₁) + 1) + ((sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos(θ
#
# ) + cos(θ₁) + 1) + ((sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅cos(θ₅) + (sin(θ₂)⋅cos
#
# (θ₂) + cos(θ₁)⋅cos(θ₂)⋅cos(θ₃) + 250.201⋅cos(θ₁)⋅cos(θ₂) + cos(θ₁) + 1) + 250.
#
#
#
# ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄))⋅(250.201⋅sin(θ₂) + 167.719) - (sin(θ₂)⋅
#
# (θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄))⋅(250.201⋅sin(θ₂) + 167.719) - (sin(θ₂
#
# 201⋅sin(θ₂) + 167.719
#
#
#
# sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + 140.54⋅(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃)
#
# )⋅sin(θ₃) - cos(θ₂)⋅cos(θ₃))⋅sin(θ₅) + 140.54⋅(sin(θ₂)⋅sin(θ₃) - cos(θ₂)⋅cos(θ
#
#
#
#
#
# )⋅cos(θ₅) - 2.785⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) + 140.54⋅(sin(θ₂
#
# ₃))⋅cos(θ₅) - 2.785⋅(sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₄) + 140.54⋅(sin(
#
#
#
#
#
# )⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(
#
# θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅sin(θ₅)⋅cos(θ₄) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅co
#
#
#
#
#
# θ₂))⋅cos(θ₄)⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 231.03⋅si
#
# s(θ₂))⋅cos(θ₄)⋅cos(θ₅) + (sin(θ₂)⋅cos(θ₃) + sin(θ₃)⋅cos(θ₂))⋅cos(θ₄) + 231.03⋅
#
#
#
#
#
# n(θ₂)⋅sin(θ₃) + sin(θ₂)⋅cos(θ₃) + 250.201⋅sin(θ₂) + sin(θ₃)⋅cos(θ₂) - 231.03⋅c
#
# sin(θ₂)⋅sin(θ₃) + sin(θ₂)⋅cos(θ₃) + 250.201⋅sin(θ₂) + sin(θ₃)⋅cos(θ₂) - 231.03
#
#
#
#
#
# os(θ₂)⋅cos(θ₃) + 167.719)⋅sin(θ₁) + 19.508⋅sin(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂) +
#
# ⋅cos(θ₂)⋅cos(θ₃) + 167.719)⋅cos(θ₁) + 250.201⋅sin(θ₁)⋅cos(θ₂) + sin(θ₁) - 19.5
#
#
#
#
#
#  cos(θ₁) + 1⎤
#             ⎥
# 08⋅cos(θ₁)  ⎥
#             ⎥
#             ⎥
#             ⎥
#             ⎦

# %%
[sp.simplify(p) for p in frames[-1]]
# Out:
# [((sin(θ₁)⋅sin(θ₄) + cos(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃))⋅cos(θ₅) - sin(θ₅)⋅sin(θ₂ +
# θ₃)⋅cos(θ₁))⋅cos(θ₆) + (sin(θ₁)⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁)⋅cos(θ₂ + θ₃))⋅sin(θ₆
# ), (-(sin(θ₁)⋅sin(θ₄) + cos(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃))⋅cos(θ₅) + sin(θ₅)⋅sin(θ₂
#  + θ₃)⋅cos(θ₁))⋅sin(θ₆) + (sin(θ₁)⋅cos(θ₄) - sin(θ₄)⋅cos(θ₁)⋅cos(θ₂ + θ₃))⋅cos
# (θ₆), (sin(θ₁)⋅sin(θ₄) + cos(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃))⋅sin(θ₅) + sin(θ₂ + θ₃)⋅
# cos(θ₁)⋅cos(θ₅), 140.54⋅sin(θ₁)⋅sin(θ₄)⋅sin(θ₅) + 1.0⋅sin(θ₁)⋅sin(θ₄)⋅cos(θ₅)
# + 1.0⋅sin(θ₁)⋅sin(θ₄) + 2.785⋅sin(θ₁)⋅cos(θ₄) + 19.508⋅sin(θ₁) - 2.785⋅sin(θ₄)
# ⋅cos(θ₁)⋅cos(θ₂ + θ₃) - sin(θ₅)⋅sin(θ₂ + θ₃)⋅cos(θ₁) + 140.54⋅sin(θ₅)⋅cos(θ₁)⋅
# cos(θ₄)⋅cos(θ₂ + θ₃) + 140.54⋅sin(θ₂ + θ₃)⋅cos(θ₁)⋅cos(θ₅) + 231.03⋅sin(θ₂ + θ
# ₃)⋅cos(θ₁) + 250.201⋅cos(θ₁)⋅cos(θ₂) + 1.0⋅cos(θ₁)⋅cos(θ₄)⋅cos(θ₅)⋅cos(θ₂ + θ₃
# ) + 1.0⋅cos(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) + 1.0⋅cos(θ₁)⋅cos(θ₂ + θ₃) + 1.0⋅cos(θ₁)
# + 1.0, ((sin(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) - sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) - sin(θ₁)⋅sin
# (θ₅)⋅sin(θ₂ + θ₃))⋅cos(θ₆) - (sin(θ₁)⋅sin(θ₄)⋅cos(θ₂ + θ₃) + cos(θ₁)⋅cos(θ₄))⋅
# sin(θ₆), ((-sin(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) + sin(θ₄)⋅cos(θ₁))⋅cos(θ₅) + sin(θ₁)⋅
# sin(θ₅)⋅sin(θ₂ + θ₃))⋅sin(θ₆) - (sin(θ₁)⋅sin(θ₄)⋅cos(θ₂ + θ₃) + cos(θ₁)⋅cos(θ₄
# ))⋅cos(θ₆), (sin(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) - sin(θ₄)⋅cos(θ₁))⋅sin(θ₅) + sin(θ₁)
# ⋅sin(θ₂ + θ₃)⋅cos(θ₅), -2.785⋅sin(θ₁)⋅sin(θ₄)⋅cos(θ₂ + θ₃) - sin(θ₁)⋅sin(θ₅)⋅s
# in(θ₂ + θ₃) + 140.54⋅sin(θ₁)⋅sin(θ₅)⋅cos(θ₄)⋅cos(θ₂ + θ₃) + 140.54⋅sin(θ₁)⋅sin
# (θ₂ + θ₃)⋅cos(θ₅) + 231.03⋅sin(θ₁)⋅sin(θ₂ + θ₃) + 250.201⋅sin(θ₁)⋅cos(θ₂) + 1.
# 0⋅sin(θ₁)⋅cos(θ₄)⋅cos(θ₅)⋅cos(θ₂ + θ₃) + 1.0⋅sin(θ₁)⋅cos(θ₄)⋅cos(θ₂ + θ₃) + 1.
# 0⋅sin(θ₁)⋅cos(θ₂ + θ₃) + 1.0⋅sin(θ₁) - 140.54⋅sin(θ₄)⋅sin(θ₅)⋅cos(θ₁) - sin(θ₄
# )⋅cos(θ₁)⋅cos(θ₅) - sin(θ₄)⋅cos(θ₁) - 2.785⋅cos(θ₁)⋅cos(θ₄) - 19.508⋅cos(θ₁),
# (sin(θ₅)⋅cos(θ₂ + θ₃) + sin(θ₂ + θ₃)⋅cos(θ₄)⋅cos(θ₅))⋅cos(θ₆) - sin(θ₄)⋅sin(θ₆
# )⋅sin(θ₂ + θ₃), -(sin(θ₅)⋅cos(θ₂ + θ₃) + sin(θ₂ + θ₃)⋅cos(θ₄)⋅cos(θ₅))⋅sin(θ₆)
#  - sin(θ₄)⋅sin(θ₂ + θ₃)⋅cos(θ₆), sin(θ₅)⋅sin(θ₂ + θ₃)⋅cos(θ₄) - cos(θ₅)⋅cos(θ₂
#  + θ₃), 250.201⋅sin(θ₂) - 2.785⋅sin(θ₄)⋅sin(θ₂ + θ₃) + 140.54⋅sin(θ₅)⋅sin(θ₂ +
#  θ₃)⋅cos(θ₄) + 1.0⋅sin(θ₅)⋅cos(θ₂ + θ₃) + 1.0⋅sin(θ₂ + θ₃)⋅cos(θ₄)⋅cos(θ₅) + 1
# .0⋅sin(θ₂ + θ₃)⋅cos(θ₄) + 1.0⋅sin(θ₂ + θ₃) - 140.54⋅cos(θ₅)⋅cos(θ₂ + θ₃) - 231
# .03⋅cos(θ₂ + θ₃) + 167.719, 0, 0, 0, 1]
